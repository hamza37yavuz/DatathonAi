# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datathonai/train.csv
# /kaggle/input/datathonai/test.csv
# /kaggle/input/datathonai/test/image_4378.jpg
# /kaggle/input/datathonai/test/image_4722.jpg
# /kaggle/input/datathonai/test/image_4432.jpg
# /kaggle/input/datathonai/test/image_4776.jpg
# /kaggle/input/datathonai/test/image_4710.jpg
# /kaggle/input/datathonai/test/image_5161.jpg
# /kaggle/input/datathonai/test/image_4953.jpg
# /kaggle/input/datathonai/test/image_4700.jpg
# /kaggle/input/datathonai/test/image_5008.jpg
# /kaggle/input/datathonai/test/image_4735.jpg
# /kaggle/input/datathonai/test/image_4752.jpg
# /kaggle/input/datathonai/test/image_4634.jpg
# /kaggle/input/datathonai/test/image_5085.jpg
# /kaggle/input/datathonai/test/image_4653.jpg
# /kaggle/input/datathonai/test/image_5025.jpg
# /kaggle/input/datathonai/test/image_5091.jpg
# /kaggle/input/datathonai/test/image_4433.jpg
# /kaggle/input/datathonai/test/image_5050.jpg
# /kaggle/input/datathonai/test/image_4683.jpg
# /kaggle/input/datathonai/test/image_4505.jpg
# /kaggle/input/datathonai/test/image_4909.jpg
# /kaggle/input/datathonai/test/image_5077.jpg
# /kaggle/input/datathonai/test/image_4379.jpg
# /kaggle/input/datathonai/test/image_4839.jpg
# /kaggle/input/datathonai/test/image_4991.jpg
# /kaggle/input/datathonai/test/image_4846.jpg
# /kaggle/input/datathonai/test/image_4850.jpg
# /kaggle/input/datathonai/test/image_4741.jpg
# /kaggle/input/datathonai/test/image_4694.jpg
# /kaggle/input/datathonai/test/image_4577.jpg
# /kaggle/input/datathonai/test/image_4698.jpg
# /kaggle/input/datathonai/test/image_4884.jpg
# /kaggle/input/datathonai/test/image_4565.jpg
# /kaggle/input/datathonai/test/image_4720.jpg
# /kaggle/input/datathonai/test/image_4900.jpg
# /kaggle/input/datathonai/test/image_4766.jpg
# /kaggle/input/datathonai/test/image_4889.jpg
# /kaggle/input/datathonai/test/image_4542.jpg
# /kaggle/input/datathonai/test/image_4853.jpg
# /kaggle/input/datathonai/test/image_4519.jpg
# /kaggle/input/datathonai/test/image_4407.jpg
# /kaggle/input/datathonai/test/image_4924.jpg
# /kaggle/input/datathonai/test/image_4905.jpg
# /kaggle/input/datathonai/test/image_5098.jpg
# /kaggle/input/datathonai/test/image_5017.jpg
# /kaggle/input/datathonai/test/image_4982.jpg
# /kaggle/input/datathonai/test/image_4623.jpg
# /kaggle/input/datathonai/test/image_4754.jpg
# /kaggle/input/datathonai/test/image_4887.jpg
# /kaggle/input/datathonai/test/image_4444.jpg
# /kaggle/input/datathonai/test/image_4517.jpg
# /kaggle/input/datathonai/test/image_4662.jpg
# /kaggle/input/datathonai/test/image_4989.jpg
# /kaggle/input/datathonai/test/image_4996.jpg
# /kaggle/input/datathonai/test/image_4697.jpg
# /kaggle/input/datathonai/test/image_4969.jpg
# /kaggle/input/datathonai/test/image_4951.jpg
# /kaggle/input/datathonai/test/image_4893.jpg
# /kaggle/input/datathonai/test/image_5148.jpg
# /kaggle/input/datathonai/test/image_4445.jpg
# /kaggle/input/datathonai/test/image_5082.jpg
# /kaggle/input/datathonai/test/image_4898.jpg
# /kaggle/input/datathonai/test/image_4490.jpg
# /kaggle/input/datathonai/test/image_4998.jpg
# /kaggle/input/datathonai/test/image_4571.jpg
# /kaggle/input/datathonai/test/image_4995.jpg
# /kaggle/input/datathonai/test/image_4629.jpg
# /kaggle/input/datathonai/test/image_4646.jpg
# /kaggle/input/datathonai/test/image_4817.jpg
# /kaggle/input/datathonai/test/image_4693.jpg
# /kaggle/input/datathonai/test/image_4977.jpg
# /kaggle/input/datathonai/test/image_5062.jpg
# /kaggle/input/datathonai/test/image_5007.jpg
# /kaggle/input/datathonai/test/image_4824.jpg
# /kaggle/input/datathonai/test/image_4899.jpg
# /kaggle/input/datathonai/test/image_4513.jpg
# /kaggle/input/datathonai/test/image_4406.jpg
# /kaggle/input/datathonai/test/image_4751.jpg
# /kaggle/input/datathonai/test/image_4715.jpg
# /kaggle/input/datathonai/test/image_5072.jpg
# /kaggle/input/datathonai/test/image_5066.jpg
# /kaggle/input/datathonai/test/image_4948.jpg
# /kaggle/input/datathonai/test/image_4812.jpg
# /kaggle/input/datathonai/test/image_4516.jpg
# /kaggle/input/datathonai/test/image_4481.jpg
# /kaggle/input/datathonai/test/image_4502.jpg
# /kaggle/input/datathonai/test/image_4990.jpg
# /kaggle/input/datathonai/test/image_5120.jpg
# /kaggle/input/datathonai/test/image_4774.jpg
# /kaggle/input/datathonai/test/image_4441.jpg
# /kaggle/input/datathonai/test/image_4756.jpg
# /kaggle/input/datathonai/test/image_4945.jpg
# /kaggle/input/datathonai/test/image_5033.jpg
# /kaggle/input/datathonai/test/image_4568.jpg
# /kaggle/input/datathonai/test/image_4934.jpg
# /kaggle/input/datathonai/test/image_5160.jpg
# /kaggle/input/datathonai/test/image_4856.jpg
# /kaggle/input/datathonai/test/image_4637.jpg
# /kaggle/input/datathonai/test/image_4957.jpg
# /kaggle/input/datathonai/test/image_5130.jpg
# /kaggle/input/datathonai/test/image_4465.jpg
# /kaggle/input/datathonai/test/image_4600.jpg
# /kaggle/input/datathonai/test/image_4494.jpg
# /kaggle/input/datathonai/test/image_4522.jpg
# /kaggle/input/datathonai/test/image_5112.jpg
# /kaggle/input/datathonai/test/image_4762.jpg
# /kaggle/input/datathonai/test/image_4831.jpg
# /kaggle/input/datathonai/test/image_4851.jpg
# /kaggle/input/datathonai/test/image_4462.jpg
# /kaggle/input/datathonai/test/image_4539.jpg
# /kaggle/input/datathonai/test/image_4400.jpg
# /kaggle/input/datathonai/test/image_4801.jpg
# /kaggle/input/datathonai/test/image_4535.jpg
# /kaggle/input/datathonai/test/image_4527.jpg
# /kaggle/input/datathonai/test/image_4453.jpg
# /kaggle/input/datathonai/test/image_5020.jpg
# /kaggle/input/datathonai/test/image_4624.jpg
# /kaggle/input/datathonai/test/image_4405.jpg
# /kaggle/input/datathonai/test/image_4835.jpg
# /kaggle/input/datathonai/test/image_4427.jpg
# /kaggle/input/datathonai/test/image_4614.jpg
# /kaggle/input/datathonai/test/image_4962.jpg
# /kaggle/input/datathonai/test/image_4970.jpg
# /kaggle/input/datathonai/test/image_4730.jpg
# /kaggle/input/datathonai/test/image_5027.jpg
# /kaggle/input/datathonai/test/image_4770.jpg
# /kaggle/input/datathonai/test/image_4782.jpg
# /kaggle/input/datathonai/test/image_4739.jpg
# /kaggle/input/datathonai/test/image_5157.jpg
# /kaggle/input/datathonai/test/image_4960.jpg
# /kaggle/input/datathonai/test/image_4607.jpg
# /kaggle/input/datathonai/test/image_5136.jpg
# /kaggle/input/datathonai/test/image_5089.jpg
# /kaggle/input/datathonai/test/image_4721.jpg
# /kaggle/input/datathonai/test/image_4576.jpg
# /kaggle/input/datathonai/test/image_4848.jpg
# /kaggle/input/datathonai/test/image_4967.jpg
# /kaggle/input/datathonai/test/image_4992.jpg
# /kaggle/input/datathonai/test/image_5024.jpg
# /kaggle/input/datathonai/test/image_4688.jpg
# /kaggle/input/datathonai/test/image_4940.jpg
# /kaggle/input/datathonai/test/image_4999.jpg
# /kaggle/input/datathonai/test/image_4486.jpg
# /kaggle/input/datathonai/test/image_5134.jpg
# /kaggle/input/datathonai/test/image_4878.jpg
# /kaggle/input/datathonai/test/image_4579.jpg
# /kaggle/input/datathonai/test/image_4392.jpg
# /kaggle/input/datathonai/test/image_5040.jpg
# /kaggle/input/datathonai/test/image_4918.jpg
# /kaggle/input/datathonai/test/image_5169.jpg
# /kaggle/input/datathonai/test/image_4758.jpg
# /kaggle/input/datathonai/test/image_4852.jpg
# /kaggle/input/datathonai/test/image_4511.jpg
# /kaggle/input/datathonai/test/image_4627.jpg
# /kaggle/input/datathonai/test/image_4540.jpg
# /kaggle/input/datathonai/test/image_5159.jpg
# /kaggle/input/datathonai/test/image_4376.jpg
# /kaggle/input/datathonai/test/image_4926.jpg
# /kaggle/input/datathonai/test/image_4811.jpg
# /kaggle/input/datathonai/test/image_4867.jpg
# /kaggle/input/datathonai/test/image_5031.jpg
# /kaggle/input/datathonai/test/image_4548.jpg
# /kaggle/input/datathonai/test/image_4733.jpg
# /kaggle/input/datathonai/test/image_4556.jpg
# /kaggle/input/datathonai/test/image_4959.jpg
# /kaggle/input/datathonai/test/image_5051.jpg
# /kaggle/input/datathonai/test/image_4621.jpg
# /kaggle/input/datathonai/test/image_4913.jpg
# /kaggle/input/datathonai/test/image_4863.jpg
# /kaggle/input/datathonai/test/image_4438.jpg
# /kaggle/input/datathonai/test/image_4673.jpg
# /kaggle/input/datathonai/test/image_4876.jpg
# /kaggle/input/datathonai/test/image_4630.jpg
# /kaggle/input/datathonai/test/image_4717.jpg
# /kaggle/input/datathonai/test/image_4467.jpg
# /kaggle/input/datathonai/test/image_5143.jpg
# /kaggle/input/datathonai/test/image_4501.jpg
# /kaggle/input/datathonai/test/image_4923.jpg
# /kaggle/input/datathonai/test/image_4869.jpg
# /kaggle/input/datathonai/test/image_4561.jpg
# /kaggle/input/datathonai/test/image_4925.jpg
# /kaggle/input/datathonai/test/image_4868.jpg
# /kaggle/input/datathonai/test/image_4901.jpg
# /kaggle/input/datathonai/test/image_4718.jpg
# /kaggle/input/datathonai/test/image_5118.jpg
# /kaggle/input/datathonai/test/image_4862.jpg
# /kaggle/input/datathonai/test/image_4655.jpg
# /kaggle/input/datathonai/test/image_4742.jpg
# /kaggle/input/datathonai/test/image_5116.jpg
# /kaggle/input/datathonai/test/image_4726.jpg
# /kaggle/input/datathonai/test/image_4937.jpg
# /kaggle/input/datathonai/test/image_4936.jpg
# /kaggle/input/datathonai/test/image_4541.jpg
# /kaggle/input/datathonai/test/image_5023.jpg
# /kaggle/input/datathonai/test/image_4870.jpg
# /kaggle/input/datathonai/test/image_4620.jpg
# /kaggle/input/datathonai/test/image_4437.jpg
# /kaggle/input/datathonai/test/image_4609.jpg
# /kaggle/input/datathonai/test/image_4906.jpg
# /kaggle/input/datathonai/test/image_5080.jpg
# /kaggle/input/datathonai/test/image_4984.jpg
# /kaggle/input/datathonai/test/image_4736.jpg
# /kaggle/input/datathonai/test/image_5060.jpg
# /kaggle/input/datathonai/test/image_4397.jpg
# /kaggle/input/datathonai/test/image_4787.jpg
# /kaggle/input/datathonai/test/image_5044.jpg
# /kaggle/input/datathonai/test/image_4608.jpg
# /kaggle/input/datathonai/test/image_4703.jpg
# /kaggle/input/datathonai/test/image_5029.jpg
# /kaggle/input/datathonai/test/image_4840.jpg
# /kaggle/input/datathonai/test/image_5052.jpg
# /kaggle/input/datathonai/test/image_4430.jpg
# /kaggle/input/datathonai/test/image_4508.jpg
# /kaggle/input/datathonai/test/image_4664.jpg
# /kaggle/input/datathonai/test/image_4775.jpg
# /kaggle/input/datathonai/test/image_4515.jpg
# /kaggle/input/datathonai/test/image_4530.jpg
# /kaggle/input/datathonai/test/image_4819.jpg
# /kaggle/input/datathonai/test/image_4454.jpg
# /kaggle/input/datathonai/test/image_4388.jpg
# /kaggle/input/datathonai/test/image_4395.jpg
# /kaggle/input/datathonai/test/image_4975.jpg
# /kaggle/input/datathonai/test/image_4725.jpg
# /kaggle/input/datathonai/test/image_4589.jpg
# /kaggle/input/datathonai/test/image_5074.jpg
# /kaggle/input/datathonai/test/image_4422.jpg
# /kaggle/input/datathonai/test/image_4849.jpg
# /kaggle/input/datathonai/test/image_4439.jpg
# /kaggle/input/datathonai/test/image_4570.jpg
# /kaggle/input/datathonai/test/image_4919.jpg
# /kaggle/input/datathonai/test/image_5036.jpg
# /kaggle/input/datathonai/test/image_5103.jpg
# /kaggle/input/datathonai/test/image_4469.jpg
# /kaggle/input/datathonai/test/image_4891.jpg
# /kaggle/input/datathonai/test/image_5147.jpg
# /kaggle/input/datathonai/test/image_5099.jpg
# /kaggle/input/datathonai/test/image_4968.jpg
# /kaggle/input/datathonai/test/image_5168.jpg
# /kaggle/input/datathonai/test/image_4691.jpg
# /kaggle/input/datathonai/test/image_4986.jpg
# /kaggle/input/datathonai/test/image_4731.jpg
# /kaggle/input/datathonai/test/image_4474.jpg
# /kaggle/input/datathonai/test/image_4834.jpg
# /kaggle/input/datathonai/test/image_4888.jpg
# /kaggle/input/datathonai/test/image_4908.jpg
# /kaggle/input/datathonai/test/image_5011.jpg
# /kaggle/input/datathonai/test/image_4686.jpg
# /kaggle/input/datathonai/test/image_4593.jpg
# /kaggle/input/datathonai/test/image_4907.jpg
# /kaggle/input/datathonai/test/image_4974.jpg
# /kaggle/input/datathonai/test/image_4667.jpg
# /kaggle/input/datathonai/test/image_4837.jpg
# /kaggle/input/datathonai/test/image_4950.jpg
# /kaggle/input/datathonai/test/image_5086.jpg
# /kaggle/input/datathonai/test/image_4523.jpg
# /kaggle/input/datathonai/test/image_4944.jpg
# /kaggle/input/datathonai/test/image_4952.jpg
# /kaggle/input/datathonai/test/image_5166.jpg
# /kaggle/input/datathonai/test/image_4976.jpg
# /kaggle/input/datathonai/test/image_5093.jpg
# /kaggle/input/datathonai/test/image_5128.jpg
# /kaggle/input/datathonai/test/image_5081.jpg
# /kaggle/input/datathonai/test/image_5167.jpg
# /kaggle/input/datathonai/test/image_4463.jpg
# /kaggle/input/datathonai/test/image_4949.jpg
# /kaggle/input/datathonai/test/image_5039.jpg
# /kaggle/input/datathonai/test/image_4492.jpg
# /kaggle/input/datathonai/test/image_4917.jpg
# /kaggle/input/datathonai/test/image_4809.jpg
# /kaggle/input/datathonai/test/image_4793.jpg
# /kaggle/input/datathonai/test/image_5035.jpg
# /kaggle/input/datathonai/test/image_4804.jpg
# /kaggle/input/datathonai/test/image_4707.jpg
# /kaggle/input/datathonai/test/image_4880.jpg
# /kaggle/input/datathonai/test/image_4734.jpg
# /kaggle/input/datathonai/test/image_4935.jpg
# /kaggle/input/datathonai/test/image_4786.jpg
# /kaggle/input/datathonai/test/image_5018.jpg
# /kaggle/input/datathonai/test/image_4922.jpg
# /kaggle/input/datathonai/test/image_5012.jpg
# /kaggle/input/datathonai/test/image_4882.jpg
# /kaggle/input/datathonai/test/image_4592.jpg
# /kaggle/input/datathonai/test/image_4798.jpg
# /kaggle/input/datathonai/test/image_5001.jpg
# /kaggle/input/datathonai/test/image_4826.jpg
# /kaggle/input/datathonai/test/image_4574.jpg
# /kaggle/input/datathonai/test/image_5106.jpg
# /kaggle/input/datathonai/test/image_5022.jpg
# /kaggle/input/datathonai/test/image_4767.jpg
# /kaggle/input/datathonai/test/image_4676.jpg
# /kaggle/input/datathonai/test/image_4844.jpg
# /kaggle/input/datathonai/test/image_4978.jpg
# /kaggle/input/datathonai/test/image_4503.jpg
# /kaggle/input/datathonai/test/image_4485.jpg
# /kaggle/input/datathonai/test/image_5010.jpg
# /kaggle/input/datathonai/test/image_4677.jpg
# /kaggle/input/datathonai/test/image_4843.jpg
# /kaggle/input/datathonai/test/image_4491.jpg
# /kaggle/input/datathonai/test/image_4479.jpg
# /kaggle/input/datathonai/test/image_4418.jpg
# /kaggle/input/datathonai/test/image_5129.jpg
# /kaggle/input/datathonai/test/image_4390.jpg
# /kaggle/input/datathonai/test/image_4446.jpg
# /kaggle/input/datathonai/test/image_4493.jpg
# /kaggle/input/datathonai/test/image_4404.jpg
# /kaggle/input/datathonai/test/image_5101.jpg
# /kaggle/input/datathonai/test/image_4813.jpg
# /kaggle/input/datathonai/test/image_4994.jpg
# /kaggle/input/datathonai/test/image_4461.jpg
# /kaggle/input/datathonai/test/image_4827.jpg
# /kaggle/input/datathonai/test/image_4399.jpg
# /kaggle/input/datathonai/test/image_4859.jpg
# /kaggle/input/datathonai/test/image_5059.jpg
# /kaggle/input/datathonai/test/image_4800.jpg
# /kaggle/input/datathonai/test/image_5013.jpg
# /kaggle/input/datathonai/test/image_5076.jpg
# /kaggle/input/datathonai/test/image_4709.jpg
# /kaggle/input/datathonai/test/image_5065.jpg
# /kaggle/input/datathonai/test/image_4586.jpg
# /kaggle/input/datathonai/test/image_4941.jpg
# /kaggle/input/datathonai/test/image_4871.jpg
# /kaggle/input/datathonai/test/image_4603.jpg
# /kaggle/input/datathonai/test/image_5096.jpg
# /kaggle/input/datathonai/test/image_4663.jpg
# /kaggle/input/datathonai/test/image_4929.jpg
# /kaggle/input/datathonai/test/image_5021.jpg
# /kaggle/input/datathonai/test/image_4478.jpg
# /kaggle/input/datathonai/test/image_4928.jpg
# /kaggle/input/datathonai/test/image_4855.jpg
# /kaggle/input/datathonai/test/image_5069.jpg
# /kaggle/input/datathonai/test/image_5071.jpg
# /kaggle/input/datathonai/test/image_4875.jpg
# /kaggle/input/datathonai/test/image_4981.jpg
# /kaggle/input/datathonai/test/image_4864.jpg
# /kaggle/input/datathonai/test/image_5123.jpg
# /kaggle/input/datathonai/test/image_4578.jpg
# /kaggle/input/datathonai/test/image_4477.jpg
# /kaggle/input/datathonai/test/image_4777.jpg
# /kaggle/input/datathonai/test/image_4987.jpg
# /kaggle/input/datathonai/test/image_4803.jpg
# /kaggle/input/datathonai/test/image_5075.jpg
# /kaggle/input/datathonai/test/image_4808.jpg
# /kaggle/input/datathonai/test/image_5004.jpg
# /kaggle/input/datathonai/test/image_4699.jpg
# /kaggle/input/datathonai/test/image_4545.jpg
# /kaggle/input/datathonai/test/image_4414.jpg
# /kaggle/input/datathonai/test/image_4588.jpg
# /kaggle/input/datathonai/test/image_5142.jpg
# /kaggle/input/datathonai/test/image_4472.jpg
# /kaggle/input/datathonai/test/image_5102.jpg
# /kaggle/input/datathonai/test/image_4732.jpg
# /kaggle/input/datathonai/test/image_4833.jpg
# /kaggle/input/datathonai/test/image_4779.jpg
# /kaggle/input/datathonai/test/image_4425.jpg
# /kaggle/input/datathonai/test/image_4679.jpg
# /kaggle/input/datathonai/test/image_4610.jpg
# /kaggle/input/datathonai/test/image_4661.jpg
# /kaggle/input/datathonai/test/image_4419.jpg
# /kaggle/input/datathonai/test/image_4743.jpg
# /kaggle/input/datathonai/test/image_4916.jpg
# /kaggle/input/datathonai/test/image_4573.jpg
# /kaggle/input/datathonai/test/image_4554.jpg
# /kaggle/input/datathonai/test/image_5145.jpg
# /kaggle/input/datathonai/test/image_4377.jpg
# /kaggle/input/datathonai/test/image_5114.jpg
# /kaggle/input/datathonai/test/image_4830.jpg
# /kaggle/input/datathonai/test/image_5049.jpg
# /kaggle/input/datathonai/test/image_4927.jpg
# /kaggle/input/datathonai/test/image_4802.jpg
# /kaggle/input/datathonai/test/image_4436.jpg
# /kaggle/input/datathonai/test/image_4560.jpg
# /kaggle/input/datathonai/test/image_5030.jpg
# /kaggle/input/datathonai/test/image_4658.jpg
# /kaggle/input/datathonai/test/image_5090.jpg
# /kaggle/input/datathonai/test/image_4702.jpg
# /kaggle/input/datathonai/test/image_4387.jpg
# /kaggle/input/datathonai/test/image_4696.jpg
# /kaggle/input/datathonai/test/image_4874.jpg
# /kaggle/input/datathonai/test/image_4567.jpg
# /kaggle/input/datathonai/test/image_4389.jpg
# /kaggle/input/datathonai/test/image_4942.jpg
# /kaggle/input/datathonai/test/image_4615.jpg
# /kaggle/input/datathonai/test/image_4410.jpg
# /kaggle/input/datathonai/test/image_4668.jpg
# /kaggle/input/datathonai/test/image_4842.jpg
# /kaggle/input/datathonai/test/image_4780.jpg
# /kaggle/input/datathonai/test/image_4814.jpg
# /kaggle/input/datathonai/test/image_4412.jpg
# /kaggle/input/datathonai/test/image_4675.jpg
# /kaggle/input/datathonai/test/image_4933.jpg
# /kaggle/input/datathonai/test/image_4606.jpg
# /kaggle/input/datathonai/test/image_4639.jpg
# /kaggle/input/datathonai/test/image_5172.jpg
# /kaggle/input/datathonai/test/image_4482.jpg
# /kaggle/input/datathonai/test/image_4633.jpg
# /kaggle/input/datathonai/test/image_4411.jpg
# /kaggle/input/datathonai/test/image_4687.jpg
# /kaggle/input/datathonai/test/image_4644.jpg
# /kaggle/input/datathonai/test/image_4921.jpg
# /kaggle/input/datathonai/test/image_4585.jpg
# /kaggle/input/datathonai/test/image_4660.jpg
# /kaggle/input/datathonai/test/image_4785.jpg
# /kaggle/input/datathonai/test/image_4599.jpg
# /kaggle/input/datathonai/test/image_4424.jpg
# /kaggle/input/datathonai/test/image_4795.jpg
# /kaggle/input/datathonai/test/image_4659.jpg
# /kaggle/input/datathonai/test/image_4794.jpg
# /kaggle/input/datathonai/test/image_4649.jpg
# /kaggle/input/datathonai/test/image_4747.jpg
# /kaggle/input/datathonai/test/image_4672.jpg
# /kaggle/input/datathonai/test/image_4381.jpg
# /kaggle/input/datathonai/test/image_4546.jpg
# /kaggle/input/datathonai/test/image_4695.jpg
# /kaggle/input/datathonai/test/image_5164.jpg
# /kaggle/input/datathonai/test/image_5138.jpg
# /kaggle/input/datathonai/test/image_4640.jpg
# /kaggle/input/datathonai/test/image_4781.jpg
# /kaggle/input/datathonai/test/image_4552.jpg
# /kaggle/input/datathonai/test/image_4483.jpg
# /kaggle/input/datathonai/test/image_5019.jpg
# /kaggle/input/datathonai/test/image_5151.jpg
# /kaggle/input/datathonai/test/image_5140.jpg
# /kaggle/input/datathonai/test/image_5108.jpg
# /kaggle/input/datathonai/test/image_4408.jpg
# /kaggle/input/datathonai/test/image_5097.jpg
# /kaggle/input/datathonai/test/image_4845.jpg
# /kaggle/input/datathonai/test/image_4825.jpg
# /kaggle/input/datathonai/test/image_4434.jpg
# /kaggle/input/datathonai/test/image_5095.jpg
# /kaggle/input/datathonai/test/image_4956.jpg
# /kaggle/input/datathonai/test/image_4791.jpg
# /kaggle/input/datathonai/test/image_4881.jpg
# /kaggle/input/datathonai/test/image_4476.jpg
# /kaggle/input/datathonai/test/image_4885.jpg
# /kaggle/input/datathonai/test/image_4521.jpg
# /kaggle/input/datathonai/test/image_4712.jpg
# /kaggle/input/datathonai/test/image_4547.jpg
# /kaggle/input/datathonai/test/image_5132.jpg
# /kaggle/input/datathonai/test/image_5135.jpg
# /kaggle/input/datathonai/test/image_4807.jpg
# /kaggle/input/datathonai/test/image_4391.jpg
# /kaggle/input/datathonai/test/image_4458.jpg
# /kaggle/input/datathonai/test/image_4510.jpg
# /kaggle/input/datathonai/test/image_4555.jpg
# /kaggle/input/datathonai/test/image_4601.jpg
# /kaggle/input/datathonai/test/image_4757.jpg
# /kaggle/input/datathonai/test/image_4810.jpg
# /kaggle/input/datathonai/test/image_4832.jpg
# /kaggle/input/datathonai/test/image_5048.jpg
# /kaggle/input/datathonai/test/image_4435.jpg
# /kaggle/input/datathonai/test/image_5146.jpg
# /kaggle/input/datathonai/test/image_5054.jpg
# /kaggle/input/datathonai/test/image_5139.jpg
# /kaggle/input/datathonai/test/image_4674.jpg
# /kaggle/input/datathonai/test/image_4534.jpg
# /kaggle/input/datathonai/test/image_4443.jpg
# /kaggle/input/datathonai/test/image_4470.jpg
# /kaggle/input/datathonai/test/image_4771.jpg
# /kaggle/input/datathonai/test/image_4963.jpg
# /kaggle/input/datathonai/test/image_5047.jpg
# /kaggle/input/datathonai/test/image_5126.jpg
# /kaggle/input/datathonai/test/image_4750.jpg
# /kaggle/input/datathonai/test/image_4890.jpg
# /kaggle/input/datathonai/test/image_5092.jpg
# /kaggle/input/datathonai/test/image_4597.jpg
# /kaggle/input/datathonai/test/image_4857.jpg
# /kaggle/input/datathonai/test/image_4860.jpg
# /kaggle/input/datathonai/test/image_4728.jpg
# /kaggle/input/datathonai/test/image_4912.jpg
# /kaggle/input/datathonai/test/image_4569.jpg
# /kaggle/input/datathonai/test/image_4602.jpg
# /kaggle/input/datathonai/test/image_4648.jpg
# /kaggle/input/datathonai/test/image_4708.jpg
# /kaggle/input/datathonai/test/image_4538.jpg
# /kaggle/input/datathonai/test/image_4716.jpg
# /kaggle/input/datathonai/test/image_4580.jpg
# /kaggle/input/datathonai/test/image_4638.jpg
# /kaggle/input/datathonai/test/image_4966.jpg
# /kaggle/input/datathonai/test/image_4764.jpg
# /kaggle/input/datathonai/test/image_5016.jpg
# /kaggle/input/datathonai/test/image_4705.jpg
# /kaggle/input/datathonai/test/image_4738.jpg
# /kaggle/input/datathonai/test/image_4402.jpg
# /kaggle/input/datathonai/test/image_4631.jpg
# /kaggle/input/datathonai/test/image_4931.jpg
# /kaggle/input/datathonai/test/image_5028.jpg
# /kaggle/input/datathonai/test/image_4759.jpg
# /kaggle/input/datathonai/test/image_4403.jpg
# /kaggle/input/datathonai/test/image_4598.jpg
# /kaggle/input/datathonai/test/image_4626.jpg
# /kaggle/input/datathonai/test/image_5170.jpg
# /kaggle/input/datathonai/test/image_4416.jpg
# /kaggle/input/datathonai/test/image_4789.jpg
# /kaggle/input/datathonai/test/image_4886.jpg
# /kaggle/input/datathonai/test/image_4939.jpg
# /kaggle/input/datathonai/test/image_4618.jpg
# /kaggle/input/datathonai/test/image_4380.jpg
# /kaggle/input/datathonai/test/image_4872.jpg
# /kaggle/input/datathonai/test/image_5171.jpg
# /kaggle/input/datathonai/test/image_5155.jpg
# /kaggle/input/datathonai/test/image_4965.jpg
# /kaggle/input/datathonai/test/image_5122.jpg
# /kaggle/input/datathonai/test/image_4605.jpg
# /kaggle/input/datathonai/test/image_4572.jpg
# /kaggle/input/datathonai/test/image_5153.jpg
# /kaggle/input/datathonai/test/image_4943.jpg
# /kaggle/input/datathonai/test/image_4822.jpg
# /kaggle/input/datathonai/test/image_4790.jpg
# /kaggle/input/datathonai/test/image_4719.jpg
# /kaggle/input/datathonai/test/image_4772.jpg
# /kaggle/input/datathonai/test/image_4983.jpg
# /kaggle/input/datathonai/test/image_5100.jpg
# /kaggle/input/datathonai/test/image_4665.jpg
# /kaggle/input/datathonai/test/image_4656.jpg
# /kaggle/input/datathonai/test/image_4796.jpg
# /kaggle/input/datathonai/test/image_4564.jpg
# /kaggle/input/datathonai/test/image_5163.jpg
# /kaggle/input/datathonai/test/image_4487.jpg
# /kaggle/input/datathonai/test/image_4612.jpg
# /kaggle/input/datathonai/test/image_4543.jpg
# /kaggle/input/datathonai/test/image_4797.jpg
# /kaggle/input/datathonai/test/image_4495.jpg
# /kaggle/input/datathonai/test/image_5141.jpg
# /kaggle/input/datathonai/test/image_4647.jpg
# /kaggle/input/datathonai/test/image_5070.jpg
# /kaggle/input/datathonai/test/image_5158.jpg
# /kaggle/input/datathonai/test/image_5162.jpg
# /kaggle/input/datathonai/test/image_5061.jpg
# /kaggle/input/datathonai/test/image_4895.jpg
# /kaggle/input/datathonai/test/image_4509.jpg
# /kaggle/input/datathonai/test/image_4604.jpg
# /kaggle/input/datathonai/test/image_4932.jpg
# /kaggle/input/datathonai/test/image_5149.jpg
# /kaggle/input/datathonai/test/image_4746.jpg
# /kaggle/input/datathonai/test/image_4488.jpg
# /kaggle/input/datathonai/test/image_5037.jpg
# /kaggle/input/datathonai/test/image_4447.jpg
# /kaggle/input/datathonai/test/image_4449.jpg
# /kaggle/input/datathonai/test/image_4706.jpg
# /kaggle/input/datathonai/test/image_4973.jpg
# /kaggle/input/datathonai/test/image_4783.jpg
# /kaggle/input/datathonai/test/image_4701.jpg
# /kaggle/input/datathonai/test/image_4727.jpg
# /kaggle/input/datathonai/test/image_4753.jpg
# /kaggle/input/datathonai/test/image_4692.jpg
# /kaggle/input/datathonai/test/image_4506.jpg
# /kaggle/input/datathonai/test/image_4684.jpg
# /kaggle/input/datathonai/test/image_4382.jpg
# /kaggle/input/datathonai/test/image_4566.jpg
# /kaggle/input/datathonai/test/image_4507.jpg
# /kaggle/input/datathonai/test/image_4765.jpg
# /kaggle/input/datathonai/test/image_4938.jpg
# /kaggle/input/datathonai/test/image_5156.jpg
# /kaggle/input/datathonai/test/image_4475.jpg
# /kaggle/input/datathonai/test/image_4768.jpg
# /kaggle/input/datathonai/test/image_5073.jpg
# /kaggle/input/datathonai/test/image_5084.jpg
# /kaggle/input/datathonai/test/image_4500.jpg
# /kaggle/input/datathonai/test/image_4971.jpg
# /kaggle/input/datathonai/test/image_4553.jpg
# /kaggle/input/datathonai/test/image_4398.jpg
# /kaggle/input/datathonai/test/image_4903.jpg
# /kaggle/input/datathonai/test/image_4806.jpg
# /kaggle/input/datathonai/test/image_4504.jpg
# /kaggle/input/datathonai/test/image_4858.jpg
# /kaggle/input/datathonai/test/image_4484.jpg
# /kaggle/input/datathonai/test/image_4724.jpg
# /kaggle/input/datathonai/test/image_4820.jpg
# /kaggle/input/datathonai/test/image_5045.jpg
# /kaggle/input/datathonai/test/image_5063.jpg
# /kaggle/input/datathonai/test/image_4525.jpg
# /kaggle/input/datathonai/test/image_4955.jpg
# /kaggle/input/datathonai/test/image_4532.jpg
# /kaggle/input/datathonai/test/image_5104.jpg
# /kaggle/input/datathonai/test/image_4459.jpg
# /kaggle/input/datathonai/test/image_4645.jpg
# /kaggle/input/datathonai/test/image_4611.jpg
# /kaggle/input/datathonai/test/image_4451.jpg
# /kaggle/input/datathonai/test/image_4596.jpg
# /kaggle/input/datathonai/test/image_4590.jpg
# /kaggle/input/datathonai/test/image_4650.jpg
# /kaggle/input/datathonai/test/image_4930.jpg
# /kaggle/input/datathonai/test/image_5046.jpg
# /kaggle/input/datathonai/test/image_4455.jpg
# /kaggle/input/datathonai/test/image_5174.jpg
# /kaggle/input/datathonai/test/image_4680.jpg
# /kaggle/input/datathonai/test/image_4678.jpg
# /kaggle/input/datathonai/test/image_4788.jpg
# /kaggle/input/datathonai/test/image_4383.jpg
# /kaggle/input/datathonai/test/image_4559.jpg
# /kaggle/input/datathonai/test/image_4910.jpg
# /kaggle/input/datathonai/test/image_4499.jpg
# /kaggle/input/datathonai/test/image_4778.jpg
# /kaggle/input/datathonai/test/image_4489.jpg
# /kaggle/input/datathonai/test/image_4980.jpg
# /kaggle/input/datathonai/test/image_4652.jpg
# /kaggle/input/datathonai/test/image_4524.jpg
# /kaggle/input/datathonai/test/image_4958.jpg
# /kaggle/input/datathonai/test/image_5113.jpg
# /kaggle/input/datathonai/test/image_4997.jpg
# /kaggle/input/datathonai/test/image_5083.jpg
# /kaggle/input/datathonai/test/image_4670.jpg
# /kaggle/input/datathonai/test/image_4854.jpg
# /kaggle/input/datathonai/test/image_4838.jpg
# /kaggle/input/datathonai/test/image_4946.jpg
# /kaggle/input/datathonai/test/image_5144.jpg
# /kaggle/input/datathonai/test/image_4428.jpg
# /kaggle/input/datathonai/test/image_4740.jpg
# /kaggle/input/datathonai/test/image_5152.jpg
# /kaggle/input/datathonai/test/image_5175.jpg
# /kaggle/input/datathonai/test/image_4587.jpg
# /kaggle/input/datathonai/test/image_5041.jpg
# /kaggle/input/datathonai/test/image_4761.jpg
# /kaggle/input/datathonai/test/image_4583.jpg
# /kaggle/input/datathonai/test/image_4385.jpg
# /kaggle/input/datathonai/test/image_5009.jpg
# /kaggle/input/datathonai/test/image_4689.jpg
# /kaggle/input/datathonai/test/image_5056.jpg
# /kaggle/input/datathonai/test/image_4533.jpg
# /kaggle/input/datathonai/test/image_5079.jpg
# /kaggle/input/datathonai/test/image_5053.jpg
# /kaggle/input/datathonai/test/image_4763.jpg
# /kaggle/input/datathonai/test/image_4818.jpg
# /kaggle/input/datathonai/test/image_4635.jpg
# /kaggle/input/datathonai/test/image_4529.jpg
# /kaggle/input/datathonai/test/image_4562.jpg
# /kaggle/input/datathonai/test/image_5115.jpg
# /kaggle/input/datathonai/test/image_4632.jpg
# /kaggle/input/datathonai/test/image_4480.jpg
# /kaggle/input/datathonai/test/image_4841.jpg
# /kaggle/input/datathonai/test/image_4520.jpg
# /kaggle/input/datathonai/test/image_4442.jpg
# /kaggle/input/datathonai/test/image_5000.jpg
# /kaggle/input/datathonai/test/image_4714.jpg
# /kaggle/input/datathonai/test/image_4904.jpg
# /kaggle/input/datathonai/test/image_4536.jpg
# /kaggle/input/datathonai/test/image_5055.jpg
# /kaggle/input/datathonai/test/image_5067.jpg
# /kaggle/input/datathonai/test/image_5125.jpg
# /kaggle/input/datathonai/test/image_4409.jpg
# /kaggle/input/datathonai/test/image_4914.jpg
# /kaggle/input/datathonai/test/image_4828.jpg
# /kaggle/input/datathonai/test/image_4401.jpg
# /kaggle/input/datathonai/test/image_5133.jpg
# /kaggle/input/datathonai/test/image_4526.jpg
# /kaggle/input/datathonai/test/image_5058.jpg
# /kaggle/input/datathonai/test/image_5127.jpg
# /kaggle/input/datathonai/test/image_4669.jpg
# /kaggle/input/datathonai/test/image_4816.jpg
# /kaggle/input/datathonai/test/image_4704.jpg
# /kaggle/input/datathonai/test/image_4557.jpg
# /kaggle/input/datathonai/test/image_4537.jpg
# /kaggle/input/datathonai/test/image_4749.jpg
# /kaggle/input/datathonai/test/image_4456.jpg
# /kaggle/input/datathonai/test/image_4954.jpg
# /kaggle/input/datathonai/test/image_4431.jpg
# /kaggle/input/datathonai/test/image_4902.jpg
# /kaggle/input/datathonai/test/image_5014.jpg
# /kaggle/input/datathonai/test/image_4654.jpg
# /kaggle/input/datathonai/test/image_5032.jpg
# /kaggle/input/datathonai/test/image_4636.jpg
# /kaggle/input/datathonai/test/image_5124.jpg
# /kaggle/input/datathonai/test/image_4865.jpg
# /kaggle/input/datathonai/test/image_4723.jpg
# /kaggle/input/datathonai/test/image_4883.jpg
# /kaggle/input/datathonai/test/image_4497.jpg
# /kaggle/input/datathonai/test/image_4879.jpg
# /kaggle/input/datathonai/test/image_4423.jpg
# /kaggle/input/datathonai/test/image_4823.jpg
# /kaggle/input/datathonai/test/image_4915.jpg
# /kaggle/input/datathonai/test/image_4911.jpg
# /kaggle/input/datathonai/test/image_4498.jpg
# /kaggle/input/datathonai/test/image_4591.jpg
# /kaggle/input/datathonai/test/image_4421.jpg
# /kaggle/input/datathonai/test/image_4558.jpg
# /kaggle/input/datathonai/test/image_4760.jpg
# /kaggle/input/datathonai/test/image_4394.jpg
# /kaggle/input/datathonai/test/image_4550.jpg
# /kaggle/input/datathonai/test/image_4628.jpg
# /kaggle/input/datathonai/test/image_4582.jpg
# /kaggle/input/datathonai/test/image_4466.jpg
# /kaggle/input/datathonai/test/image_5003.jpg
# /kaggle/input/datathonai/test/image_5173.jpg
# /kaggle/input/datathonai/test/image_4528.jpg
# /kaggle/input/datathonai/test/image_4448.jpg
# /kaggle/input/datathonai/test/image_4622.jpg
# /kaggle/input/datathonai/test/image_4393.jpg
# /kaggle/input/datathonai/test/image_4873.jpg
# /kaggle/input/datathonai/test/image_4847.jpg
# /kaggle/input/datathonai/test/image_4613.jpg
# /kaggle/input/datathonai/test/image_4617.jpg
# /kaggle/input/datathonai/test/image_4920.jpg
# /kaggle/input/datathonai/test/image_4420.jpg
# /kaggle/input/datathonai/test/image_5005.jpg
# /kaggle/input/datathonai/test/image_4384.jpg
# /kaggle/input/datathonai/test/image_4784.jpg
# /kaggle/input/datathonai/test/image_4815.jpg
# /kaggle/input/datathonai/test/image_4671.jpg
# /kaggle/input/datathonai/test/image_4877.jpg
# /kaggle/input/datathonai/test/image_4685.jpg
# /kaggle/input/datathonai/test/image_4643.jpg
# /kaggle/input/datathonai/test/image_5150.jpg
# /kaggle/input/datathonai/test/image_4471.jpg
# /kaggle/input/datathonai/test/image_4836.jpg
# /kaggle/input/datathonai/test/image_4616.jpg
# /kaggle/input/datathonai/test/image_4745.jpg
# /kaggle/input/datathonai/test/image_4651.jpg
# /kaggle/input/datathonai/test/image_5026.jpg
# /kaggle/input/datathonai/test/image_4581.jpg
# /kaggle/input/datathonai/test/image_4594.jpg
# /kaggle/input/datathonai/test/image_4440.jpg
# /kaggle/input/datathonai/test/image_5087.jpg
# /kaggle/input/datathonai/test/image_5109.jpg
# /kaggle/input/datathonai/test/image_5043.jpg
# /kaggle/input/datathonai/test/image_5088.jpg
# /kaggle/input/datathonai/test/image_5154.jpg
# /kaggle/input/datathonai/test/image_4711.jpg
# /kaggle/input/datathonai/test/image_4551.jpg
# /kaggle/input/datathonai/test/image_5068.jpg
# /kaggle/input/datathonai/test/image_4595.jpg
# /kaggle/input/datathonai/test/image_4429.jpg
# /kaggle/input/datathonai/test/image_5034.jpg
# /kaggle/input/datathonai/test/image_4468.jpg
# /kaggle/input/datathonai/test/image_4892.jpg
# /kaggle/input/datathonai/test/image_5006.jpg
# /kaggle/input/datathonai/test/image_4894.jpg
# /kaggle/input/datathonai/test/image_4544.jpg
# /kaggle/input/datathonai/test/image_4821.jpg
# /kaggle/input/datathonai/test/image_5015.jpg
# /kaggle/input/datathonai/test/image_4619.jpg
# /kaggle/input/datathonai/test/image_4413.jpg
# /kaggle/input/datathonai/test/image_4993.jpg
# /kaggle/input/datathonai/test/image_4426.jpg
# /kaggle/input/datathonai/test/image_4460.jpg
# /kaggle/input/datathonai/test/image_5119.jpg
# /kaggle/input/datathonai/test/image_5002.jpg
# /kaggle/input/datathonai/test/image_4464.jpg
# /kaggle/input/datathonai/test/image_4897.jpg
# /kaggle/input/datathonai/test/image_4457.jpg
# /kaggle/input/datathonai/test/image_5105.jpg
# /kaggle/input/datathonai/test/image_4961.jpg
# /kaggle/input/datathonai/test/image_4496.jpg
# /kaggle/input/datathonai/test/image_5121.jpg
# /kaggle/input/datathonai/test/image_4748.jpg
# /kaggle/input/datathonai/test/image_4829.jpg
# /kaggle/input/datathonai/test/image_4682.jpg
# /kaggle/input/datathonai/test/image_5057.jpg
# /kaggle/input/datathonai/test/image_4792.jpg
# /kaggle/input/datathonai/test/image_5110.jpg
# /kaggle/input/datathonai/test/image_5137.jpg
# /kaggle/input/datathonai/test/image_4514.jpg
# /kaggle/input/datathonai/test/image_4755.jpg
# /kaggle/input/datathonai/test/image_5111.jpg
# /kaggle/input/datathonai/test/image_4799.jpg
# /kaggle/input/datathonai/test/image_4452.jpg
# /kaggle/input/datathonai/test/image_4866.jpg
# /kaggle/input/datathonai/test/image_5078.jpg
# /kaggle/input/datathonai/test/image_5042.jpg
# /kaggle/input/datathonai/test/image_4773.jpg
# /kaggle/input/datathonai/test/image_4415.jpg
# /kaggle/input/datathonai/test/image_4642.jpg
# /kaggle/input/datathonai/test/image_4531.jpg
# /kaggle/input/datathonai/test/image_4690.jpg
# /kaggle/input/datathonai/test/image_4641.jpg
# /kaggle/input/datathonai/test/image_4549.jpg
# /kaggle/input/datathonai/test/image_5107.jpg
# /kaggle/input/datathonai/test/image_4737.jpg
# /kaggle/input/datathonai/test/image_4964.jpg
# /kaggle/input/datathonai/test/image_4473.jpg
# /kaggle/input/datathonai/test/image_4805.jpg
# /kaggle/input/datathonai/test/image_4518.jpg
# /kaggle/input/datathonai/test/image_4947.jpg
# /kaggle/input/datathonai/test/image_4972.jpg
# /kaggle/input/datathonai/test/image_4396.jpg
# /kaggle/input/datathonai/test/image_4988.jpg
# /kaggle/input/datathonai/test/image_4417.jpg
# /kaggle/input/datathonai/test/image_4896.jpg
# /kaggle/input/datathonai/test/image_4666.jpg
# /kaggle/input/datathonai/test/image_4681.jpg
# /kaggle/input/datathonai/test/image_4625.jpg
# /kaggle/input/datathonai/test/image_4729.jpg
# /kaggle/input/datathonai/test/image_4563.jpg
# /kaggle/input/datathonai/test/image_4744.jpg
# /kaggle/input/datathonai/test/image_4979.jpg
# /kaggle/input/datathonai/test/image_5064.jpg
# /kaggle/input/datathonai/test/image_4575.jpg
# /kaggle/input/datathonai/test/image_4861.jpg
# /kaggle/input/datathonai/test/image_4769.jpg
# /kaggle/input/datathonai/test/image_4386.jpg
# /kaggle/input/datathonai/test/image_4985.jpg
# /kaggle/input/datathonai/test/image_5094.jpg
# /kaggle/input/datathonai/test/image_5165.jpg
# /kaggle/input/datathonai/test/image_5117.jpg
# /kaggle/input/datathonai/test/image_5038.jpg
# /kaggle/input/datathonai/test/image_4512.jpg
# /kaggle/input/datathonai/test/image_4450.jpg
# /kaggle/input/datathonai/test/image_5131.jpg
# /kaggle/input/datathonai/test/image_4713.jpg
# /kaggle/input/datathonai/test/image_4657.jpg
# /kaggle/input/datathonai/test/image_4584.jpg
# /kaggle/input/datathonai/train/image_0612.jpg
# /kaggle/input/datathonai/train/image_3019.jpg
# /kaggle/input/datathonai/train/image_2566.jpg
# /kaggle/input/datathonai/train/image_0946.jpg
# /kaggle/input/datathonai/train/image_0755.jpg
# /kaggle/input/datathonai/train/image_0178.jpg
# /kaggle/input/datathonai/train/image_3156.jpg
# /kaggle/input/datathonai/train/image_3889.jpg
# /kaggle/input/datathonai/train/image_2951.jpg
# /kaggle/input/datathonai/train/image_1593.jpg
# /kaggle/input/datathonai/train/image_4172.jpg
# /kaggle/input/datathonai/train/image_3513.jpg
# /kaggle/input/datathonai/train/image_3480.jpg
# /kaggle/input/datathonai/train/image_3641.jpg
# /kaggle/input/datathonai/train/image_1975.jpg
# /kaggle/input/datathonai/train/image_0777.jpg
# /kaggle/input/datathonai/train/image_0998.jpg
# /kaggle/input/datathonai/train/image_0073.jpg
# /kaggle/input/datathonai/train/image_2104.jpg
# /kaggle/input/datathonai/train/image_1769.jpg
# /kaggle/input/datathonai/train/image_3227.jpg
# /kaggle/input/datathonai/train/image_2008.jpg
# /kaggle/input/datathonai/train/image_4368.jpg
# /kaggle/input/datathonai/train/image_2013.jpg
# /kaggle/input/datathonai/train/image_3367.jpg
# /kaggle/input/datathonai/train/image_2526.jpg
# /kaggle/input/datathonai/train/image_3609.jpg
# /kaggle/input/datathonai/train/image_0123.jpg
# /kaggle/input/datathonai/train/image_2078.jpg
# /kaggle/input/datathonai/train/image_0770.jpg
# /kaggle/input/datathonai/train/image_3000.jpg
# /kaggle/input/datathonai/train/image_2105.jpg
# /kaggle/input/datathonai/train/image_2534.jpg
# /kaggle/input/datathonai/train/image_1103.jpg
# /kaggle/input/datathonai/train/image_0219.jpg
# /kaggle/input/datathonai/train/image_0270.jpg
# /kaggle/input/datathonai/train/image_0188.jpg
# /kaggle/input/datathonai/train/image_2165.jpg
# /kaggle/input/datathonai/train/image_2088.jpg
# /kaggle/input/datathonai/train/image_3466.jpg
# /kaggle/input/datathonai/train/image_0772.jpg
# /kaggle/input/datathonai/train/image_1576.jpg
# /kaggle/input/datathonai/train/image_0677.jpg
# /kaggle/input/datathonai/train/image_1808.jpg
# /kaggle/input/datathonai/train/image_3456.jpg
# /kaggle/input/datathonai/train/image_2394.jpg
# /kaggle/input/datathonai/train/image_1168.jpg
# /kaggle/input/datathonai/train/image_2426.jpg
# /kaggle/input/datathonai/train/image_2323.jpg
# /kaggle/input/datathonai/train/image_0491.jpg
# /kaggle/input/datathonai/train/image_2864.jpg
# /kaggle/input/datathonai/train/image_2538.jpg
# /kaggle/input/datathonai/train/image_1340.jpg
# /kaggle/input/datathonai/train/image_1400.jpg
# /kaggle/input/datathonai/train/image_0089.jpg
# /kaggle/input/datathonai/train/image_1185.jpg
# /kaggle/input/datathonai/train/image_0773.jpg
# /kaggle/input/datathonai/train/image_3628.jpg
# /kaggle/input/datathonai/train/image_2002.jpg
# /kaggle/input/datathonai/train/image_2292.jpg
# /kaggle/input/datathonai/train/image_0217.jpg
# /kaggle/input/datathonai/train/image_4235.jpg
# /kaggle/input/datathonai/train/image_0540.jpg
# /kaggle/input/datathonai/train/image_1963.jpg
# /kaggle/input/datathonai/train/image_3560.jpg
# /kaggle/input/datathonai/train/image_1860.jpg
# /kaggle/input/datathonai/train/image_1585.jpg
# /kaggle/input/datathonai/train/image_1621.jpg
# /kaggle/input/datathonai/train/image_0040.jpg
# /kaggle/input/datathonai/train/image_3887.jpg
# /kaggle/input/datathonai/train/image_3225.jpg
# /kaggle/input/datathonai/train/image_3643.jpg
# /kaggle/input/datathonai/train/image_2866.jpg
# /kaggle/input/datathonai/train/image_3176.jpg
# /kaggle/input/datathonai/train/image_0340.jpg
# /kaggle/input/datathonai/train/image_3054.jpg
# /kaggle/input/datathonai/train/image_2439.jpg
# /kaggle/input/datathonai/train/image_1890.jpg
# /kaggle/input/datathonai/train/image_0985.jpg
# /kaggle/input/datathonai/train/image_3543.jpg
# /kaggle/input/datathonai/train/image_0499.jpg
# /kaggle/input/datathonai/train/image_1075.jpg
# /kaggle/input/datathonai/train/image_1969.jpg
# /kaggle/input/datathonai/train/image_0481.jpg
# /kaggle/input/datathonai/train/image_3186.jpg
# /kaggle/input/datathonai/train/image_1335.jpg
# /kaggle/input/datathonai/train/image_3144.jpg
# /kaggle/input/datathonai/train/image_2392.jpg
# /kaggle/input/datathonai/train/image_0719.jpg
# /kaggle/input/datathonai/train/image_0030.jpg
# /kaggle/input/datathonai/train/image_0348.jpg
# /kaggle/input/datathonai/train/image_0248.jpg
# /kaggle/input/datathonai/train/image_0327.jpg
# /kaggle/input/datathonai/train/image_3762.jpg
# /kaggle/input/datathonai/train/image_3088.jpg
# /kaggle/input/datathonai/train/image_1610.jpg
# /kaggle/input/datathonai/train/image_1677.jpg
# /kaggle/input/datathonai/train/image_2644.jpg
# /kaggle/input/datathonai/train/image_0091.jpg
# /kaggle/input/datathonai/train/image_3350.jpg
# /kaggle/input/datathonai/train/image_0643.jpg
# /kaggle/input/datathonai/train/image_3522.jpg
# /kaggle/input/datathonai/train/image_1889.jpg
# /kaggle/input/datathonai/train/image_0183.jpg
# /kaggle/input/datathonai/train/image_1571.jpg
# /kaggle/input/datathonai/train/image_1828.jpg
# /kaggle/input/datathonai/train/image_1772.jpg
# /kaggle/input/datathonai/train/image_4093.jpg
# /kaggle/input/datathonai/train/image_0733.jpg
# /kaggle/input/datathonai/train/image_0157.jpg
# /kaggle/input/datathonai/train/image_4283.jpg
# /kaggle/input/datathonai/train/image_2899.jpg
# /kaggle/input/datathonai/train/image_2468.jpg
# /kaggle/input/datathonai/train/image_0482.jpg
# /kaggle/input/datathonai/train/image_3869.jpg
# /kaggle/input/datathonai/train/image_3905.jpg
# /kaggle/input/datathonai/train/image_2872.jpg
# /kaggle/input/datathonai/train/image_1491.jpg
# /kaggle/input/datathonai/train/image_3807.jpg
# /kaggle/input/datathonai/train/image_2987.jpg
# /kaggle/input/datathonai/train/image_1266.jpg
# /kaggle/input/datathonai/train/image_0503.jpg
# /kaggle/input/datathonai/train/image_4294.jpg
# /kaggle/input/datathonai/train/image_2448.jpg
# /kaggle/input/datathonai/train/image_0062.jpg
# /kaggle/input/datathonai/train/image_0749.jpg
# /kaggle/input/datathonai/train/image_0303.jpg
# /kaggle/input/datathonai/train/image_1695.jpg
# /kaggle/input/datathonai/train/image_1797.jpg
# /kaggle/input/datathonai/train/image_1360.jpg
# /kaggle/input/datathonai/train/image_0509.jpg
# /kaggle/input/datathonai/train/image_2981.jpg
# /kaggle/input/datathonai/train/image_0763.jpg
# /kaggle/input/datathonai/train/image_2073.jpg
# /kaggle/input/datathonai/train/image_2844.jpg
# /kaggle/input/datathonai/train/image_4275.jpg
# /kaggle/input/datathonai/train/image_2488.jpg
# /kaggle/input/datathonai/train/image_2384.jpg
# /kaggle/input/datathonai/train/image_0789.jpg
# /kaggle/input/datathonai/train/image_1724.jpg
# /kaggle/input/datathonai/train/image_1065.jpg
# /kaggle/input/datathonai/train/image_4192.jpg
# /kaggle/input/datathonai/train/image_4280.jpg
# /kaggle/input/datathonai/train/image_0454.jpg
# /kaggle/input/datathonai/train/image_0600.jpg
# /kaggle/input/datathonai/train/image_3768.jpg
# /kaggle/input/datathonai/train/image_0190.jpg
# /kaggle/input/datathonai/train/image_0513.jpg
# /kaggle/input/datathonai/train/image_3067.jpg
# /kaggle/input/datathonai/train/image_1235.jpg
# /kaggle/input/datathonai/train/image_2259.jpg
# /kaggle/input/datathonai/train/image_2370.jpg
# /kaggle/input/datathonai/train/image_1417.jpg
# /kaggle/input/datathonai/train/image_1949.jpg
# /kaggle/input/datathonai/train/image_0253.jpg
# /kaggle/input/datathonai/train/image_3007.jpg
# /kaggle/input/datathonai/train/image_4117.jpg
# /kaggle/input/datathonai/train/image_1731.jpg
# /kaggle/input/datathonai/train/image_1547.jpg
# /kaggle/input/datathonai/train/image_3881.jpg
# /kaggle/input/datathonai/train/image_0614.jpg
# /kaggle/input/datathonai/train/image_1598.jpg
# /kaggle/input/datathonai/train/image_1339.jpg
# /kaggle/input/datathonai/train/image_0458.jpg
# /kaggle/input/datathonai/train/image_3073.jpg
# /kaggle/input/datathonai/train/image_3014.jpg
# /kaggle/input/datathonai/train/image_3049.jpg
# /kaggle/input/datathonai/train/image_1189.jpg
# /kaggle/input/datathonai/train/image_2671.jpg
# /kaggle/input/datathonai/train/image_3590.jpg
# /kaggle/input/datathonai/train/image_0268.jpg
# /kaggle/input/datathonai/train/image_0203.jpg
# /kaggle/input/datathonai/train/image_3968.jpg
# /kaggle/input/datathonai/train/image_4221.jpg
# /kaggle/input/datathonai/train/image_1321.jpg
# /kaggle/input/datathonai/train/image_3541.jpg
# /kaggle/input/datathonai/train/image_3616.jpg
# /kaggle/input/datathonai/train/image_1447.jpg
# /kaggle/input/datathonai/train/image_2715.jpg
# /kaggle/input/datathonai/train/image_0096.jpg
# /kaggle/input/datathonai/train/image_0155.jpg
# /kaggle/input/datathonai/train/image_1409.jpg
# /kaggle/input/datathonai/train/image_4195.jpg
# /kaggle/input/datathonai/train/image_2111.jpg
# /kaggle/input/datathonai/train/image_4035.jpg
# /kaggle/input/datathonai/train/image_1063.jpg
# /kaggle/input/datathonai/train/image_1924.jpg
# /kaggle/input/datathonai/train/image_2298.jpg
# /kaggle/input/datathonai/train/image_0175.jpg
# /kaggle/input/datathonai/train/image_2403.jpg
# /kaggle/input/datathonai/train/image_2881.jpg
# /kaggle/input/datathonai/train/image_4246.jpg
# /kaggle/input/datathonai/train/image_0759.jpg
# /kaggle/input/datathonai/train/image_2195.jpg
# /kaggle/input/datathonai/train/image_0291.jpg
# /kaggle/input/datathonai/train/image_1635.jpg
# /kaggle/input/datathonai/train/image_2490.jpg
# /kaggle/input/datathonai/train/image_3400.jpg
# /kaggle/input/datathonai/train/image_0686.jpg
# /kaggle/input/datathonai/train/image_0883.jpg
# /kaggle/input/datathonai/train/image_4341.jpg
# /kaggle/input/datathonai/train/image_4233.jpg
# /kaggle/input/datathonai/train/image_1355.jpg
# /kaggle/input/datathonai/train/image_3475.jpg
# /kaggle/input/datathonai/train/image_3916.jpg
# /kaggle/input/datathonai/train/image_3051.jpg
# /kaggle/input/datathonai/train/image_3030.jpg
# /kaggle/input/datathonai/train/image_1948.jpg
# /kaggle/input/datathonai/train/image_1516.jpg
# /kaggle/input/datathonai/train/image_4073.jpg
# /kaggle/input/datathonai/train/image_1038.jpg
# /kaggle/input/datathonai/train/image_3139.jpg
# /kaggle/input/datathonai/train/image_4179.jpg
# /kaggle/input/datathonai/train/image_0371.jpg
# /kaggle/input/datathonai/train/image_2248.jpg
# /kaggle/input/datathonai/train/image_0795.jpg
# /kaggle/input/datathonai/train/image_1334.jpg
# /kaggle/input/datathonai/train/image_3151.jpg
# /kaggle/input/datathonai/train/image_1840.jpg
# /kaggle/input/datathonai/train/image_3257.jpg
# /kaggle/input/datathonai/train/image_0866.jpg
# /kaggle/input/datathonai/train/image_2085.jpg
# /kaggle/input/datathonai/train/image_0645.jpg
# /kaggle/input/datathonai/train/image_2637.jpg
# /kaggle/input/datathonai/train/image_2880.jpg
# /kaggle/input/datathonai/train/image_3964.jpg
# /kaggle/input/datathonai/train/image_0314.jpg
# /kaggle/input/datathonai/train/image_2357.jpg
# /kaggle/input/datathonai/train/image_0653.jpg
# /kaggle/input/datathonai/train/image_2229.jpg
# /kaggle/input/datathonai/train/image_3455.jpg
# /kaggle/input/datathonai/train/image_2037.jpg
# /kaggle/input/datathonai/train/image_1389.jpg
# /kaggle/input/datathonai/train/image_1972.jpg
# /kaggle/input/datathonai/train/image_1754.jpg
# /kaggle/input/datathonai/train/image_0020.jpg
# /kaggle/input/datathonai/train/image_1643.jpg
# /kaggle/input/datathonai/train/image_1470.jpg
# /kaggle/input/datathonai/train/image_3755.jpg
# /kaggle/input/datathonai/train/image_0235.jpg
# /kaggle/input/datathonai/train/image_3059.jpg
# /kaggle/input/datathonai/train/image_1896.jpg
# /kaggle/input/datathonai/train/image_2704.jpg
# /kaggle/input/datathonai/train/image_3306.jpg
# /kaggle/input/datathonai/train/image_2942.jpg
# /kaggle/input/datathonai/train/image_1452.jpg
# /kaggle/input/datathonai/train/image_0044.jpg
# /kaggle/input/datathonai/train/image_1683.jpg
# /kaggle/input/datathonai/train/image_0333.jpg
# /kaggle/input/datathonai/train/image_0687.jpg
# /kaggle/input/datathonai/train/image_1504.jpg
# /kaggle/input/datathonai/train/image_3952.jpg
# /kaggle/input/datathonai/train/image_1337.jpg
# /kaggle/input/datathonai/train/image_3994.jpg
# /kaggle/input/datathonai/train/image_1787.jpg
# /kaggle/input/datathonai/train/image_3321.jpg
# /kaggle/input/datathonai/train/image_0625.jpg
# /kaggle/input/datathonai/train/image_0299.jpg
# /kaggle/input/datathonai/train/image_3992.jpg
# ...
# /kaggle/input/datathonai/train/image_1465.jpg
# /kaggle/input/datathonai/train/image_1307.jpg
# /kaggle/input/datathonai/train/image_4354.jpg
# /kaggle/input/datathonai/train/image_3383.jpg
# /kaggle/input/datathonai/train/image_3512.jpg
# /kaggle/input/datathonai/train/image_2652.jpg
# /kaggle/input/datathonai/train/image_2420.jpg
# /kaggle/input/datathonai/train/image_1898.jpg
# /kaggle/input/datathonai/train/image_2813.jpg
# /kaggle/input/datathonai/train/image_0361.jpg
# /kaggle/input/datathonai/train/image_2543.jpg
# /kaggle/input/datathonai/train/image_1415.jpg
# /kaggle/input/datathonai/train/image_0390.jpg
# /kaggle/input/datathonai/train/image_2968.jpg
# /kaggle/input/datathonai/train/image_3554.jpg
# /kaggle/input/datathonai/train/image_1845.jpg
# /kaggle/input/datathonai/train/image_2024.jpg
# /kaggle/input/datathonai/train/image_2266.jpg
# /kaggle/input/datathonai/train/image_2836.jpg
# /kaggle/input/datathonai/train/image_2367.jpg
# /kaggle/input/datathonai/train/image_2276.jpg
# /kaggle/input/datathonai/train/image_1102.jpg
# /kaggle/input/datathonai/train/image_0632.jpg
# /kaggle/input/datathonai/train/image_4203.jpg
# /kaggle/input/datathonai/train/image_1153.jpg
# /kaggle/input/datathonai/train/image_3654.jpg
# /kaggle/input/datathonai/train/image_1826.jpg
# /kaggle/input/datathonai/train/image_2495.jpg
# /kaggle/input/datathonai/train/image_1609.jpg
# /kaggle/input/datathonai/train/image_1240.jpg
# /kaggle/input/datathonai/train/image_0943.jpg
# /kaggle/input/datathonai/train/image_1934.jpg
# /kaggle/input/datathonai/train/image_4136.jpg
# /kaggle/input/datathonai/train/image_0294.jpg
# /kaggle/input/datathonai/train/image_1476.jpg
# /kaggle/input/datathonai/train/image_1582.jpg
# /kaggle/input/datathonai/train/image_2567.jpg
# /kaggle/input/datathonai/train/image_0858.jpg
# /kaggle/input/datathonai/train/image_1375.jpg
# /kaggle/input/datathonai/train/image_4347.jpg
# /kaggle/input/datathonai/train/image_0529.jpg
# /kaggle/input/datathonai/train/image_1212.jpg
# /kaggle/input/datathonai/train/image_2513.jpg
# /kaggle/input/datathonai/train/image_2625.jpg
# /kaggle/input/datathonai/train/image_0507.jpg
# /kaggle/input/datathonai/train/image_0918.jpg
# /kaggle/input/datathonai/train/image_3953.jpg
# /kaggle/input/datathonai/train/image_3507.jpg
# /kaggle/input/datathonai/train/image_1031.jpg
# /kaggle/input/datathonai/train/image_1988.jpg
# /kaggle/input/datathonai/train/image_2173.jpg
# /kaggle/input/datathonai/train/image_0536.jpg
# /kaggle/input/datathonai/train/image_0949.jpg
# /kaggle/input/datathonai/train/image_0256.jpg
# /kaggle/input/datathonai/train/image_1272.jpg
# /kaggle/input/datathonai/train/image_2667.jpg
# /kaggle/input/datathonai/train/image_4197.jpg
# /kaggle/input/datathonai/train/image_3557.jpg
# /kaggle/input/datathonai/train/image_2257.jpg
# /kaggle/input/datathonai/train/image_0583.jpg
# /kaggle/input/datathonai/train/image_1299.jpg
# /kaggle/input/datathonai/train/image_3514.jpg
# /kaggle/input/datathonai/train/image_2520.jpg
# /kaggle/input/datathonai/train/image_3582.jpg
# /kaggle/input/datathonai/train/image_0861.jpg
# /kaggle/input/datathonai/train/image_3775.jpg
# /kaggle/input/datathonai/train/image_3618.jpg
# /kaggle/input/datathonai/train/image_3344.jpg
# /kaggle/input/datathonai/train/image_2663.jpg
# /kaggle/input/datathonai/train/image_0641.jpg
# /kaggle/input/datathonai/train/image_3550.jpg
# /kaggle/input/datathonai/train/image_4115.jpg
# /kaggle/input/datathonai/train/image_0812.jpg
# /kaggle/input/datathonai/train/image_3598.jpg
# /kaggle/input/datathonai/train/image_3705.jpg
# /kaggle/input/datathonai/train/image_1326.jpg
# /kaggle/input/datathonai/train/image_2811.jpg
# /kaggle/input/datathonai/train/image_1715.jpg
# /kaggle/input/datathonai/train/image_0121.jpg
# /kaggle/input/datathonai/train/image_0132.jpg
# /kaggle/input/datathonai/train/image_3911.jpg
# /kaggle/input/datathonai/train/image_3284.jpg
# /kaggle/input/datathonai/train/image_0471.jpg
# /kaggle/input/datathonai/train/image_0136.jpg
# /kaggle/input/datathonai/train/image_1111.jpg
# /kaggle/input/datathonai/train/image_0839.jpg
# /kaggle/input/datathonai/train/image_1158.jpg
# /kaggle/input/datathonai/train/image_0059.jpg
# /kaggle/input/datathonai/train/image_1569.jpg
# /kaggle/input/datathonai/train/image_0329.jpg
# /kaggle/input/datathonai/train/image_3046.jpg
# /kaggle/input/datathonai/train/image_4267.jpg
# /kaggle/input/datathonai/train/image_0574.jpg
# /kaggle/input/datathonai/train/image_0027.jpg
# /kaggle/input/datathonai/train/image_3052.jpg
# /kaggle/input/datathonai/train/image_2979.jpg
# /kaggle/input/datathonai/train/image_2022.jpg
# /kaggle/input/datathonai/train/image_2925.jpg
# /kaggle/input/datathonai/train/image_2751.jpg
# /kaggle/input/datathonai/train/image_0561.jpg
# /kaggle/input/datathonai/train/image_4312.jpg
# /kaggle/input/datathonai/train/image_1175.jpg
# /kaggle/input/datathonai/train/image_3578.jpg
# /kaggle/input/datathonai/train/image_1429.jpg
# /kaggle/input/datathonai/train/image_0993.jpg
# /kaggle/input/datathonai/train/image_4010.jpg
# /kaggle/input/datathonai/train/image_3102.jpg
# /kaggle/input/datathonai/train/image_2903.jpg
# /kaggle/input/datathonai/train/image_2615.jpg
# /kaggle/input/datathonai/train/image_3914.jpg
# /kaggle/input/datathonai/train/image_3235.jpg
# /kaggle/input/datathonai/train/image_0097.jpg
# /kaggle/input/datathonai/train/image_3140.jpg
# /kaggle/input/datathonai/train/image_1289.jpg
# /kaggle/input/datathonai/train/image_3841.jpg
# /kaggle/input/datathonai/train/image_3285.jpg
# /kaggle/input/datathonai/train/image_0063.jpg
# /kaggle/input/datathonai/train/image_3462.jpg
# /kaggle/input/datathonai/train/image_1886.jpg
# /kaggle/input/datathonai/train/image_1829.jpg
# /kaggle/input/datathonai/train/image_3547.jpg
# /kaggle/input/datathonai/train/image_2817.jpg
# /kaggle/input/datathonai/train/image_1025.jpg
# /kaggle/input/datathonai/train/image_4104.jpg
# /kaggle/input/datathonai/train/image_3720.jpg
# /kaggle/input/datathonai/train/image_1941.jpg
# /kaggle/input/datathonai/train/image_4348.jpg
# /kaggle/input/datathonai/train/image_0821.jpg
# /kaggle/input/datathonai/train/image_2621.jpg
# /kaggle/input/datathonai/train/image_2862.jpg
# /kaggle/input/datathonai/train/image_0971.jpg
# /kaggle/input/datathonai/train/image_1301.jpg
# /kaggle/input/datathonai/train/image_2578.jpg
# /kaggle/input/datathonai/train/image_4085.jpg
# /kaggle/input/datathonai/train/image_1496.jpg
# /kaggle/input/datathonai/train/image_4335.jpg
# /kaggle/input/datathonai/train/image_1032.jpg
# /kaggle/input/datathonai/train/image_1302.jpg
# /kaggle/input/datathonai/train/image_3100.jpg
# /kaggle/input/datathonai/train/image_2136.jpg
# /kaggle/input/datathonai/train/image_0702.jpg
# /kaggle/input/datathonai/train/image_0505.jpg
# /kaggle/input/datathonai/train/image_4345.jpg
# /kaggle/input/datathonai/train/image_2062.jpg
# /kaggle/input/datathonai/train/image_2224.jpg
# /kaggle/input/datathonai/train/image_0086.jpg
# /kaggle/input/datathonai/train/image_2310.jpg
# /kaggle/input/datathonai/train/image_1156.jpg
# /kaggle/input/datathonai/train/image_0167.jpg
# /kaggle/input/datathonai/train/image_1414.jpg
# /kaggle/input/datathonai/train/image_0016.jpg
# /kaggle/input/datathonai/train/image_3949.jpg
# /kaggle/input/datathonai/train/image_0395.jpg
# /kaggle/input/datathonai/train/image_1003.jpg
# /kaggle/input/datathonai/train/image_2260.jpg
# /kaggle/input/datathonai/train/image_3988.jpg
# /kaggle/input/datathonai/train/image_2957.jpg
# /kaggle/input/datathonai/train/image_0569.jpg
# /kaggle/input/datathonai/train/image_3530.jpg
# /kaggle/input/datathonai/train/image_2302.jpg
# /kaggle/input/datathonai/train/image_1759.jpg
# /kaggle/input/datathonai/train/image_4331.jpg
# /kaggle/input/datathonai/train/image_0940.jpg
# /kaggle/input/datathonai/train/image_3426.jpg
# /kaggle/input/datathonai/train/image_1742.jpg
# /kaggle/input/datathonai/train/image_2056.jpg
# /kaggle/input/datathonai/train/image_3366.jpg
# /kaggle/input/datathonai/train/image_3831.jpg
# /kaggle/input/datathonai/train/image_0260.jpg
# /kaggle/input/datathonai/train/image_0924.jpg
# /kaggle/input/datathonai/train/image_1606.jpg
# /kaggle/input/datathonai/train/image_4215.jpg
# /kaggle/input/datathonai/train/image_3546.jpg
# /kaggle/input/datathonai/train/image_3118.jpg
# /kaggle/input/datathonai/train/image_0431.jpg
# /kaggle/input/datathonai/train/image_2325.jpg
# /kaggle/input/datathonai/train/image_1434.jpg
# /kaggle/input/datathonai/train/image_0808.jpg
# /kaggle/input/datathonai/train/image_0774.jpg
# /kaggle/input/datathonai/train/image_3474.jpg
# /kaggle/input/datathonai/train/image_1761.jpg
# /kaggle/input/datathonai/train/image_3359.jpg
# /kaggle/input/datathonai/train/image_3931.jpg
# /kaggle/input/datathonai/train/image_1792.jpg
# /kaggle/input/datathonai/train/image_3682.jpg
# /kaggle/input/datathonai/train/image_0508.jpg
# /kaggle/input/datathonai/train/image_1767.jpg
# /kaggle/input/datathonai/train/image_1443.jpg
# /kaggle/input/datathonai/train/image_0820.jpg
# /kaggle/input/datathonai/train/image_3419.jpg
# /kaggle/input/datathonai/train/image_1047.jpg
# /kaggle/input/datathonai/train/image_1698.jpg
# /kaggle/input/datathonai/train/image_3429.jpg
# /kaggle/input/datathonai/train/image_2512.jpg
# /kaggle/input/datathonai/train/image_0346.jpg
# /kaggle/input/datathonai/train/image_2210.jpg
# /kaggle/input/datathonai/train/image_3444.jpg
# /kaggle/input/datathonai/train/image_2936.jpg
# /kaggle/input/datathonai/train/image_0382.jpg
# /kaggle/input/datathonai/train/image_4253.jpg
# /kaggle/input/datathonai/train/image_4170.jpg
# /kaggle/input/datathonai/train/image_1239.jpg
# /kaggle/input/datathonai/train/image_1131.jpg
# /kaggle/input/datathonai/train/image_2186.jpg
# /kaggle/input/datathonai/train/image_0598.jpg
# /kaggle/input/datathonai/train/image_4022.jpg
# /kaggle/input/datathonai/train/image_1323.jpg
# /kaggle/input/datathonai/train/image_1489.jpg
# /kaggle/input/datathonai/train/image_2449.jpg
# /kaggle/input/datathonai/train/image_1249.jpg
# /kaggle/input/datathonai/train/image_0864.jpg
# /kaggle/input/datathonai/train/image_2576.jpg
# /kaggle/input/datathonai/train/image_0312.jpg
# /kaggle/input/datathonai/train/image_2760.jpg
# /kaggle/input/datathonai/train/image_0800.jpg
# /kaggle/input/datathonai/train/image_0879.jpg
# /kaggle/input/datathonai/train/image_4008.jpg
# /kaggle/input/datathonai/train/image_0765.jpg
# /kaggle/input/datathonai/train/image_0372.jpg
# /kaggle/input/datathonai/train/image_3963.jpg
# /kaggle/input/datathonai/train/image_3293.jpg
# /kaggle/input/datathonai/train/image_1097.jpg
# /kaggle/input/datathonai/train/image_1110.jpg
# /kaggle/input/datathonai/train/image_2686.jpg
# /kaggle/input/datathonai/train/image_0667.jpg
# /kaggle/input/datathonai/train/image_3939.jpg
# /kaggle/input/datathonai/train/image_0922.jpg
# /kaggle/input/datathonai/train/image_2592.jpg
# /kaggle/input/datathonai/train/image_0074.jpg
# /kaggle/input/datathonai/train/image_0181.jpg
# /kaggle/input/datathonai/train/image_1672.jpg
# /kaggle/input/datathonai/train/image_1588.jpg
# /kaggle/input/datathonai/train/image_0112.jpg
# /kaggle/input/datathonai/train/image_1164.jpg
# /kaggle/input/datathonai/train/image_3852.jpg
# /kaggle/input/datathonai/train/image_0274.jpg
# /kaggle/input/datathonai/train/image_2887.jpg
# /kaggle/input/datathonai/train/image_2291.jpg
# /kaggle/input/datathonai/train/image_1351.jpg
# /kaggle/input/datathonai/train/image_1367.jpg
# /kaggle/input/datathonai/train/image_2233.jpg
# /kaggle/input/datathonai/train/image_0093.jpg
# /kaggle/input/datathonai/train/image_0246.jpg
# /kaggle/input/datathonai/train/image_1021.jpg
# /kaggle/input/datathonai/train/image_2672.jpg
# /kaggle/input/datathonai/train/image_2374.jpg
# /kaggle/input/datathonai/train/image_3042.jpg
# /kaggle/input/datathonai/train/image_2494.jpg
# /kaggle/input/datathonai/train/image_0168.jpg
# /kaggle/input/datathonai/train/image_2858.jpg
# /kaggle/input/datathonai/train/image_2594.jpg
# /kaggle/input/datathonai/train/image_1344.jpg
# /kaggle/input/datathonai/train/image_0160.jpg
# /kaggle/input/datathonai/train/image_3787.jpg
# /kaggle/input/datathonai/train/image_1070.jpg
# /kaggle/input/datathonai/train/image_3478.jpg
# /kaggle/input/datathonai/train/image_2331.jpg
# /kaggle/input/datathonai/train/image_3380.jpg
# /kaggle/input/datathonai/train/image_2193.jpg
# /kaggle/input/datathonai/train/image_2345.jpg
# /kaggle/input/datathonai/train/image_1147.jpg
# /kaggle/input/datathonai/train/image_0071.jpg
# /kaggle/input/datathonai/train/image_2382.jpg
# /kaggle/input/datathonai/train/image_2992.jpg
# /kaggle/input/datathonai/train/image_4065.jpg
# /kaggle/input/datathonai/train/image_1509.jpg
# /kaggle/input/datathonai/train/image_2167.jpg
# /kaggle/input/datathonai/train/image_4000.jpg
# /kaggle/input/datathonai/train/image_0501.jpg
# /kaggle/input/datathonai/train/image_0712.jpg
# /kaggle/input/datathonai/train/image_2707.jpg
# /kaggle/input/datathonai/train/image_2549.jpg
# /kaggle/input/datathonai/train/image_2797.jpg
# /kaggle/input/datathonai/train/image_4164.jpg
# /kaggle/input/datathonai/train/image_2120.jpg
# /kaggle/input/datathonai/train/image_3558.jpg
# /kaggle/input/datathonai/train/image_3043.jpg
# /kaggle/input/datathonai/train/image_2041.jpg
# /kaggle/input/datathonai/train/image_0711.jpg
# /kaggle/input/datathonai/train/image_0276.jpg
# /kaggle/input/datathonai/train/image_0761.jpg
# /kaggle/input/datathonai/train/image_0785.jpg
# /kaggle/input/datathonai/train/image_3229.jpg
# /kaggle/input/datathonai/train/image_1187.jpg
# /kaggle/input/datathonai/train/image_3057.jpg
# /kaggle/input/datathonai/train/image_3038.jpg
# /kaggle/input/datathonai/train/image_0341.jpg
# /kaggle/input/datathonai/train/image_0533.jpg
# /kaggle/input/datathonai/train/image_3845.jpg
# /kaggle/input/datathonai/train/image_2309.jpg
# /kaggle/input/datathonai/train/image_0043.jpg
# /kaggle/input/datathonai/train/image_1391.jpg
# /kaggle/input/datathonai/train/image_1014.jpg
# /kaggle/input/datathonai/train/image_1198.jpg
# /kaggle/input/datathonai/train/image_1897.jpg
# /kaggle/input/datathonai/train/image_0413.jpg
# /kaggle/input/datathonai/train/image_2741.jpg
# /kaggle/input/datathonai/train/image_3873.jpg
# /kaggle/input/datathonai/train/image_1515.jpg
# /kaggle/input/datathonai/train/image_2118.jpg
# /kaggle/input/datathonai/train/image_0416.jpg
# /kaggle/input/datathonai/train/image_1821.jpg
# /kaggle/input/datathonai/train/image_1668.jpg
# /kaggle/input/datathonai/train/image_0024.jpg
# /kaggle/input/datathonai/train/image_0611.jpg
# /kaggle/input/datathonai/train/image_1758.jpg
# /kaggle/input/datathonai/train/image_4191.jpg
# /kaggle/input/datathonai/train/image_1740.jpg
# /kaggle/input/datathonai/train/image_3815.jpg
# /kaggle/input/datathonai/train/image_2965.jpg
# /kaggle/input/datathonai/train/image_3593.jpg
# /kaggle/input/datathonai/train/image_1708.jpg
# /kaggle/input/datathonai/train/image_3505.jpg
# /kaggle/input/datathonai/train/image_2371.jpg
# /kaggle/input/datathonai/train/image_4308.jpg
# /kaggle/input/datathonai/train/image_3009.jpg
# /kaggle/input/datathonai/train/image_2401.jpg
# /kaggle/input/datathonai/train/image_0926.jpg
# /kaggle/input/datathonai/train/image_2599.jpg
# /kaggle/input/datathonai/train/image_2163.jpg
# /kaggle/input/datathonai/train/image_1108.jpg
# /kaggle/input/datathonai/train/image_3358.jpg
# /kaggle/input/datathonai/train/image_1091.jpg
# /kaggle/input/datathonai/train/image_2947.jpg
# /kaggle/input/datathonai/train/image_3411.jpg
# /kaggle/input/datathonai/train/image_0311.jpg
# /kaggle/input/datathonai/train/image_3468.jpg
# /kaggle/input/datathonai/train/image_2456.jpg
# /kaggle/input/datathonai/train/image_1192.jpg
# /kaggle/input/datathonai/train/image_1455.jpg
# /kaggle/input/datathonai/train/image_1136.jpg
# /kaggle/input/datathonai/train/image_2507.jpg
# /kaggle/input/datathonai/train/image_3836.jpg
# /kaggle/input/datathonai/train/image_2262.jpg
# /kaggle/input/datathonai/train/image_3665.jpg
# /kaggle/input/datathonai/train/image_3287.jpg
# /kaggle/input/datathonai/train/image_1193.jpg
# /kaggle/input/datathonai/train/image_0193.jpg
# /kaggle/input/datathonai/train/image_0955.jpg
# /kaggle/input/datathonai/train/image_0576.jpg
# /kaggle/input/datathonai/train/image_2252.jpg
# /kaggle/input/datathonai/train/image_0356.jpg
# /kaggle/input/datathonai/train/image_1287.jpg
# /kaggle/input/datathonai/train/image_3081.jpg
# /kaggle/input/datathonai/train/image_2577.jpg
# /kaggle/input/datathonai/train/image_4129.jpg
# /kaggle/input/datathonai/train/image_0415.jpg

# %%
import os
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader, random_split

from torchvision.transforms import (
    Compose,
    Resize,
    RandomHorizontalFlip,
    RandomRotation,
    RandomResizedCrop,
    ToTensor,
    Normalize
)

from transformers import AutoModelForImageClassification, AutoImageProcessor
import matplotlib.pyplot as plt
from tqdm import tqdm
import math


#############################
# 1. Normalizasyon Değerleri
#############################
LAT_MEAN = 41.10
LAT_STD = 0.002358
LON_MEAN = 29.02
LON_STD = 0.004205

BATCH_SIZE = 32
NUM_EPOCHS = 10
LEARNING_RATE = 5e-3


#############################
# 2. Haversine Mesafesi
#############################
def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # Dünya yarıçapı (km)
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = (torch.sin(dlat / 2))**2 + torch.cos(lat1) * torch.cos(lat2) * (torch.sin(dlon / 2))**2
    c = 2 * torch.arcsin(torch.sqrt(a))
    return R * c


def normalize_latlon(lat, lon):
    """
    Latitude ve longitude değerlerini normalleştirir.
    """
    lat_norm = (lat - LAT_MEAN) / LAT_STD
    lon_norm = (lon - LON_MEAN) / LON_STD
    return lat_norm, lon_norm


def denormalize_latlon(lat_norm, lon_norm):
    """
    Normalleştirilmiş latitude ve longitude değerlerini gerçek değerlere çevirir.
    """
    lat = lat_norm * LAT_STD + LAT_MEAN
    lon = lon_norm * LON_STD + LON_MEAN
    return lat, lon


#############################
# 3. Veri Seti Sınıfı
#############################
class GeoDataset(Dataset):
    def __init__(self, csv_path, root_dir, transform=None, sep=';'):
        self.data_df = pd.read_csv(csv_path, sep=sep)
        self.root_dir = root_dir
        self.transform = transform

        self.filenames = self.data_df["filename"].values
        self.lats = self.data_df["latitude"].fillna(0.0).values
        self.lons = self.data_df["longitude"].fillna(0.0).values

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, idx):
        img_name = self.filenames[idx]
        lat = self.lats[idx]
        lon = self.lons[idx]

        lat_norm, lon_norm = normalize_latlon(lat, lon)

        img_path = os.path.join(self.root_dir, img_name)
        image = Image.open(img_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        coords = torch.tensor([lat_norm, lon_norm], dtype=torch.float32)
        return image, coords, img_name


#############################
# 4. Transform ve Dataset
#############################
image_size = 224
transform = Compose([
    Resize((image_size, image_size)),
    RandomHorizontalFlip(),
    RandomRotation(10),
    RandomResizedCrop(image_size, scale=(0.8, 1.0)),
    ToTensor(),
    Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # ImageNet normalization
])

train_csv_path = "/kaggle/input/datathonai/train.csv"
train_images_dir = "/kaggle/input/datathonai/train"

dataset = GeoDataset(
    csv_path=train_csv_path,
    root_dir=train_images_dir,
    transform=transform
)
print("Train+Val Dataset Size:", len(dataset))

train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)


#############################
# 5. Test Dataset
#############################
test_csv_path = "/kaggle/input/datathonai/test.csv"
test_images_dir = "/kaggle/input/datathonai/test"

test_dataset = GeoDataset(
    csv_path=test_csv_path,
    root_dir=test_images_dir,
    transform=transform
)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)


#############################
# 6. ConvNeXt Modeli
#############################
model = AutoModelForImageClassification.from_pretrained(
    "facebook/convnextv2-large-1k-224",
    num_labels=2,
    ignore_mismatched_sizes=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.device_count() > 1:
    model = nn.DataParallel(model)
model.to(device)


#############################
# 7. Kayıp Fonksiyonu, Optimizasyon, Scheduler
#############################
criterion = nn.MSELoss()
optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=1, verbose=True)


#############################
# 8. Eğitim Döngüsü
#############################
train_losses = []
val_losses = []

for epoch in range(NUM_EPOCHS):
    print(f"\nEpoch {epoch+1}/{NUM_EPOCHS}")
    model.train()
    running_loss = 0.0

    for images, coords, _ in tqdm(train_loader, desc="Training"):
        images = images.to(device)
        coords = coords.to(device)

        optimizer.zero_grad()
        outputs = model(pixel_values=images)
        logits = outputs.logits
        loss = criterion(logits, coords)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    train_loss = running_loss / len(train_loader)
    train_losses.append(train_loss)

    # Validation
    model.eval()
    val_running_loss = 0.0
    distances = []
    with torch.no_grad():
        for val_images, val_coords, _ in tqdm(val_loader, desc="Validation"):
            val_images = val_images.to(device)
            val_coords = val_coords.to(device)

            val_logits = model(pixel_values=val_images).logits
            val_loss = criterion(val_logits, val_coords)
            val_running_loss += val_loss.item()

            for i in range(val_logits.size(0)):
                pred_lat_norm, pred_lon_norm = val_logits[i]
                pred_lat, pred_lon = denormalize_latlon(pred_lat_norm, pred_lon_norm)
                true_lat, true_lon = denormalize_latlon(val_coords[i][0], val_coords[i][1])

                dist = haversine_distance(
                    torch.tensor([math.radians(pred_lat)]),
                    torch.tensor([math.radians(pred_lon)]),
                    torch.tensor([math.radians(true_lat)]),
                    torch.tensor([math.radians(true_lon)])
                )
                distances.append(dist.item())

    val_loss = val_running_loss / len(val_loader)
    val_losses.append(val_loss)

    mean_distance = sum(distances) / len(distances)
    print(f"Train Loss: {train_loss:.5f} | Val Loss: {val_loss:.5f} | Mean Distance: {mean_distance:.5f} km")

    scheduler.step(val_loss)

    # Test Tahminleri
    model.eval()
    test_preds = []
    test_filenames = []
    with torch.no_grad():
        for test_images, _, test_names in tqdm(test_loader, desc="Test Inference"):
            test_images = test_images.to(device)
            test_out = model(pixel_values=test_images).logits

            for i, fname in enumerate(test_names):
                pred_lat_norm, pred_lon_norm = test_out[i]
                pred_lat, pred_lon = denormalize_latlon(pred_lat_norm, pred_lon_norm)
                test_preds.append((pred_lat.item(), pred_lon.item()))
                test_filenames.append(fname)

    df_test_out = pd.DataFrame({
        "filename": test_filenames,
        "latitude": [p[0] for p in test_preds],
        "longitude": [p[1] for p in test_preds]
    })
    test_csv_path = f"test_predictions_epoch_{epoch+1}.csv"
    df_test_out.to_csv(test_csv_path, sep=';', index=False)

    model_save_path = f"convnextv2_epoch_{epoch+1}.pth"
    torch.save(model.state_dict(), model_save_path)

print("Eğitim tamamlandı!")
# Out:
# Train+Val Dataset Size: 4375
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/792M [00:00<?, ?B/s]
# Some weights of ConvNextV2ForImageClassification were not initialized from the model checkpoint at facebook/convnextv2-large-1k-224 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 1536]) in the checkpoint and torch.Size([2, 1536]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([2]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/10
# Training: 100%|██████████| 124/124 [17:54<00:00,  8.66s/it]
# Validation: 100%|██████████| 14/14 [01:52<00:00,  8.07s/it]
# Train Loss: 0.64960 | Val Loss: 0.36601 | Mean Distance: 0.21700 km
# Test Inference: 100%|██████████| 25/25 [03:15<00:00,  7.82s/it]
# Epoch 2/10
# Training: 100%|██████████| 124/124 [16:22<00:00,  7.93s/it]
# Validation: 100%|██████████| 14/14 [01:37<00:00,  6.96s/it]
# Train Loss: 0.21678 | Val Loss: 0.19913 | Mean Distance: 0.15016 km
# Test Inference: 100%|██████████| 25/25 [02:51<00:00,  6.87s/it]
# Epoch 3/10
# Training: 100%|██████████| 124/124 [16:24<00:00,  7.94s/it]
# Validation: 100%|██████████| 14/14 [01:36<00:00,  6.92s/it]
# Train Loss: 0.08687 | Val Loss: 0.14443 | Mean Distance: 0.12170 km
# Test Inference: 100%|██████████| 25/25 [02:50<00:00,  6.83s/it]
# Epoch 4/10
# Training: 100%|██████████| 124/124 [16:28<00:00,  7.97s/it]
# Validation: 100%|██████████| 14/14 [01:39<00:00,  7.09s/it]
# Train Loss: 0.04434 | Val Loss: 0.11014 | Mean Distance: 0.10523 km
# Test Inference: 100%|██████████| 25/25 [02:51<00:00,  6.86s/it]
# Epoch 5/10
# Training: 100%|██████████| 124/124 [16:21<00:00,  7.92s/it]
# Validation: 100%|██████████| 14/14 [01:36<00:00,  6.89s/it]
# Train Loss: 0.02770 | Val Loss: 0.11071 | Mean Distance: 0.09946 km
# Test Inference: 100%|██████████| 25/25 [02:50<00:00,  6.84s/it]
# Epoch 6/10
# Training: 100%|██████████| 124/124 [16:20<00:00,  7.91s/it]
# Validation: 100%|██████████| 14/14 [01:36<00:00,  6.86s/it]
# Train Loss: 0.01964 | Val Loss: 0.09250 | Mean Distance: 0.09228 km
# Test Inference: 100%|██████████| 25/25 [02:48<00:00,  6.76s/it]
# Epoch 7/10
# Training: 100%|██████████| 124/124 [16:24<00:00,  7.94s/it]
# Validation: 100%|██████████| 14/14 [01:35<00:00,  6.84s/it]
# Train Loss: 0.01478 | Val Loss: 0.09718 | Mean Distance: 0.08938 km
# Test Inference: 100%|██████████| 25/25 [02:48<00:00,  6.72s/it]
# Epoch 8/10
# Training: 100%|██████████| 124/124 [16:21<00:00,  7.91s/it]
# Validation: 100%|██████████| 14/14 [01:37<00:00,  6.94s/it]
# Train Loss: 0.01250 | Val Loss: 0.09354 | Mean Distance: 0.08636 km
# Test Inference: 100%|██████████| 25/25 [02:51<00:00,  6.86s/it]
# Epoch 9/10
# Training: 100%|██████████| 124/124 [16:23<00:00,  7.93s/it]
# Validation: 100%|██████████| 14/14 [01:36<00:00,  6.89s/it]
# Train Loss: 0.00838 | Val Loss: 0.08382 | Mean Distance: 0.08102 km
# Test Inference: 100%|██████████| 25/25 [02:49<00:00,  6.79s/it]
# Epoch 10/10
# Training: 100%|██████████| 124/124 [16:17<00:00,  7.88s/it]
# Validation: 100%|██████████| 14/14 [01:35<00:00,  6.84s/it]
# Train Loss: 0.00703 | Val Loss: 0.08163 | Mean Distance: 0.07857 km
# Test Inference: 100%|██████████| 25/25 [02:49<00:00,  6.77s/it]
# Eğitim tamamlandı!
